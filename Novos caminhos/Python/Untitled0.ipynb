# %%
num1 = int(input())
num2 = int(input())

print(num1)
print(type(num1))
print(num1+num2)
print(num1+num1)
print(num1-num2)
print(num1*num2)
print(num1/num2)
print(num1&num2)
# Out:
# 200
# 10
# 200
# <class 'int'>
# 210
# 400
# 190
# 2000
# 20.0
# 8

# %% [markdown]
# https://www.for.gov.bc.ca/ftp/hre/external/!publish/becmaps/PaperMaps/field/DLI_LillooetSubunit_CascadesResourceDistrict_ThompsonOkanaganRegion__field.pdf
